# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
datapath1=r'C:\Users\User\Desktop\計量經濟學\Growth.csv'
growthData = pd.read_csv(datapath1,sep = ',',engine='python',encoding = 'utf-8')

# %%
growthData.set_index('country_name' , inplace=True)

# %%
growthData['growth']
# Out:
# country_name
# India                  1.915168
# Argentina              0.617645
# Japan                  4.304759
# Brazil                 2.930097
# United States          1.712265
# Bangladesh             0.708263
# Spain                  2.880327
# Colombia               2.227014
# Peru                   0.060206
# Haiti                 -0.657934
# Australia              1.975147
# Italy                  2.932981
# Greece                 3.224050
# France                 2.431281
# Zaire                 -2.811944
# Uruguay                1.025309
# Mexico                 1.973942
# Pakistan               2.698163
# Niger                 -2.751478
# Bolivia                0.355058
# Germany                2.453688
# Canada                 2.385988
# United Kingdom         1.962219
# New Zealand            1.124132
# Philippines            1.158741
# Finland                2.798494
# Venezuela             -0.883551
# Korea, Republic of     7.156855
# Guatemala              0.929231
# Honduras               0.597785
#                          ...
# Trinidad and Tobago    1.120786
# Ecuador                2.388093
# Denmark                2.179370
# Switzerland            1.421865
# Austria                2.889185
# Zimbabwe               0.838156
# Paraguay               2.381932
# Costa Rica             1.613697
# Portugal               3.647310
# Togo                   0.462775
# Iceland                3.012389
# Israel                 2.810969
# South Africa           0.392021
# Norway                 3.182494
# Sierra Leone          -0.339834
# Dominican Republic     2.498769
# Ghana                 -0.963162
# Sri Lanka              2.704598
# Taiwan, China          6.624734
# Panama                 2.027189
# Papua New Guinea       1.120371
# Kenya                  1.962509
# Ireland                3.254494
# Jamaica                0.417790
# Netherlands            2.200577
# Cyprus                 5.384184
# Malaysia               4.114544
# Belgium                2.651335
# Mauritius              3.024178
# Malta                  6.652838
# Name: growth, Length: 65, dtype: float64

# %%
growthData.index(growthData['India'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'India'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-1e0fec2edb80> in <module>()
# ----> 1 growthData.index(growthData['India'])
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    2487         res = cache.get(item)
#    2488         if res is None:
# -> 2489             values = self._data.get(item)
#    2490             res = self._box_item_values(item, values)
#    2491             cache[item] = res
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
# -> 3080                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3081
#    3082         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'India'

# %%
plt.figure(figsize=(16,4))
plt.plot(data1['country_name'])

# %%
import sys
import webbrowser


url = 'https://www.abc-mart.com.tw/views/size-guide.php'

#while(True):
size = input("請輸入你的鞋子日碼:")
size_float = float(size)
size_length = len(str(size))
size_dic = {'22.5':'35', '23.0':'36','23.5':'37','24.0':'38','24.5':'39','25.0':'40'}
if size_length==4 and size_float%0.5 == 0 and size_float >= 22.5 and size_float <= 25:
    print("您的鞋子日碼換算成歐碼為:"+str(size_dic['{}'.format(size_float)]))
elif size_length==2 and size_float > 22 and size_float < 26:
    print("您的鞋子日碼換算成歐碼為:"+str(size_dic['{}'.format(size_float)]))
elif size_float < 22.5:
    print("不好意思我們沒有計算到那麼小的腳ㄚ!請您移至這個網站查詢!")
    webbrowser.open(url)
elif size_float > 25:
    print("不好意思我們沒有計算到那麼大的腳ㄚ!請您移至這個網站查詢!")
    webbrowser.open(url)
else:
    print("請輸入正確日碼喔!如:23.5!")
    print(size_length,size_float,size_float%5)
# Out:
# 請輸入你的鞋子日碼:23.5
# 您的鞋子日碼換算成歐碼為:37

# %%
23.0%0.5
# Out:
# 0.0
