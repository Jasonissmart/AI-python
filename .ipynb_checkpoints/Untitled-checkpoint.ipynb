# %% [markdown]
# # 自訂一個list,畫出(plot)類似「M」的形狀。

# %%
# %pylab inline

x= [1,1,2,3,3]
y= [0,5,1,5,0]

xticks(x)
yticks(y)

# 避免被圖表元素被蓋住
plt.tight_layout()

plot(x, y, '-o')
plt.show()
fig = plt.figure(figsize=(8, 4))
# Out:
# Populating the interactive namespace from numpy and matplotlib
