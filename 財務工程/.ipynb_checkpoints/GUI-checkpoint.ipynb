# %%
import tkinter as tk
import numpy as np
import matplotlib as plt
plt.use("TkAgg")
from matplotlib.figure import Figure
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg

# 主視窗
win = tk.Tk() 
win.title("Risk-free rate")
win.geometry("1200x750+100+30") 
win.minsize(width = 1200, height = 700)
win.config(background="#D6D6EA" )
win.attributes("-topmost", 0)

# Smith-Wilson法
smws = tk.Label(text="Smith-Wilson",bg="#D6D6EA", fg="#000AFF" )
smws.config(font="微軟正黑體 20")
smws.place(x=600, y=50)


smws_anrt = tk.Label(text="Input annual rates",bg="#ffffff", fg="#000000" )
smws_anrt.config(font="微軟正黑體 15")
smws_anrt.place(x=600, y=100)

smws_anrt1 = tk.Label(text="Zero, Bond, Swap",bg="#D6D6EA", fg="#6B6B91" )
smws_anrt1.config(font="微軟正黑體 10")
smws_anrt1.place(x=600, y=135)

swanrt_en = tk.Entry(font="微軟正黑體 15")
swanrt_en.config(width=5)
swanrt_en.place(x=800, y=100)


smws_cpnfr = tk.Label(text="Coupon frequency",bg="#ffffff", fg="#000000" )
smws_cpnfr.config(font="微軟正黑體 15")
smws_cpnfr.place(x=600, y=170)

smws_cpnfr1 = tk.Label(text="coupons per year(only used for Bond and Swap)",bg="#D6D6EA", fg="#6B6B91" )
smws_cpnfr1.config(font="微軟正黑體 10")
smws_cpnfr1.place(x=600, y=205)

swUFR_cpnfr = tk.Entry(font="微軟正黑體 15")
swUFR_cpnfr.config(width=5)
swUFR_cpnfr.place(x=800, y=170)


smws_CRA = tk.Label(text="CRA applied \n to input rates",bg="#ffffff", fg="#000000" )
smws_CRA.config(font="微軟正黑體 13")
smws_CRA.place(x=600, y=240)

smws_CRA1 = tk.Label(text="basispoints",bg="#D6D6EA", fg="#6B6B91" )
smws_CRA1.config(font="微軟正黑體 8")
smws_CRA1.place(x=600, y=290)

swCRA_en = tk.Entry(font="微軟正黑體 15")
swCRA_en.config(width=5)
swCRA_en.place(x=800, y=240)


smws_UFR = tk.Label(text="UFR",bg="#ffffff", fg="#000000" )
smws_UFR.config(font="微軟正黑體 15")
smws_UFR.place(x=600, y=310)

smws_UFR1 = tk.Label(text="Annual compounded rate",bg="#D6D6EA", fg="#6B6B91" )
smws_UFR1.config(font="微軟正黑體 10")
smws_UFR1.place(x=600, y=345)

swUFR_en = tk.Entry(font="微軟正黑體 15")
swUFR_en.config(width=5)
swUFR_en.place(x=800, y=310)


smws_minal = tk.Label(text="Minimum alpha",bg="#ffffff", fg="#000000" )
smws_minal.config(font="微軟正黑體 15")
smws_minal.place(x=600, y=380)

swminal_en = tk.Entry(font="微軟正黑體 15")
swminal_en.config(width=5)
swminal_en.place(x=800, y=380)


smws_Bcnv = tk.Label(text="Bandwith\nconvergence UFR",bg="#ffffff", fg="#000000" )
smws_Bcnv.config(font="微軟正黑體 13")
smws_Bcnv.place(x=600, y=450)

smws_Bcnv1 = tk.Label(text="basispoint intensity",bg="#D6D6EA", fg="#6B6B91" )
smws_Bcnv1.config(font="微軟正黑體 8")
smws_Bcnv1.place(x=600, y=500)

swBcnv_en = tk.Entry(font="微軟正黑體 15")
swBcnv_en.config(width=5)
swBcnv_en.place(x=800, y=450)


smws_convT = tk.Label(text="Convergence at T=",bg="#ffffff", fg="#000000" )
smws_convT.config(font="微軟正黑體 15")
smws_convT.place(x=600, y=520)

smws_convT1 = tk.Label(text="Years",bg="#D6D6EA", fg="#6B6B91" )
smws_convT1.config(font="微軟正黑體 10")
smws_convT1.place(x=600, y=555)

swconvT_en = tk.Entry(font="微軟正黑體 15")
swconvT_en.config(width=5)
swconvT_en.place(x=800, y=520)


smws_Liq = tk.Label(text="Liquid?",bg="#ffffff", fg="#000000" )
smws_Liq.config(font="微軟正黑體 15")
smws_Liq.place(x=600, y=590)

smws_UFR1 = tk.Label(text="(1=Y/0=N)",bg="#D6D6EA", fg="#6B6B91" )
smws_UFR1.config(font="微軟正黑體 10")
smws_UFR1.place(x=600, y=625)

swLiq_en = tk.Entry(font="微軟正黑體 15")
swLiq_en.config(width=5)
swLiq_en.place(x=800, y=590)






def SW_getinput():
    swanrt_en_val = swanrt_en.get()         #input annual rate
    swUFR_cpnfr_val = swUFR_cpnfr.get()     #coupon frequency
    swCRA_en_val = swCRA_en.get()           #CRA applied to input rates
    swUFR_en_val = swUFR_en.get()           #UFR
    swminal_en_val = swminal_en.get()       #minimun alpha
    swBcnv_en_val = swBcnv_en.get()         #bandwith convergence UFR
    swconvT_en_val = swconvT_en.get()       #convergence at T
    swLiq_en_val = swLiq_en.get()           #Liquid
    import configparser
    config = configparser.ConfigParser()     # 創建對象
    config.read('config.ini', encoding='utf-8')
    config.set("Parameter","instrument",str(swanrt_en_val))
    config.set("Parameter","cra",str(swCRA_en_val))
    config.set("Parameter","ufrac",str(swUFR_en_val))
    config.set("Parameter","alfamin",str(swminal_en_val))
    config.set("Parameter","t2",str(swconvT_en_val))
    config.write(open("config.ini","w"))

    
    
swipt = tk.Button()
swipt.config(fg="#000000", bg="#ffffff", text="Input Data", font="微軟正黑體 15",command=SW_getinput) #****************
swipt.place(x=620, y=680)

# Cubic-Spline

cbsp = tk.Label(text="Cubic-Spline",bg="#D6D6EA", fg="#000AFF" )
cbsp.config(font="微軟正黑體 20")
cbsp.place(x=900, y=50)


cbsp_anrt = tk.Label(text="Input annual rates",bg="#ffffff", fg="#000000" )
cbsp_anrt.config(font="微軟正黑體 15")
cbsp_anrt.place(x=900, y=100)

cbsp_anrt1 = tk.Label(text="Zero, Bond, Csap",bg="#D6D6EA", fg="#6B6B91" )
cbsp_anrt1.config(font="微軟正黑體 10")
cbsp_anrt1.place(x=900, y=135)

csanrt_en = tk.Entry(font="微軟正黑體 15")
csanrt_en.config(width=5)
csanrt_en.place(x=1100, y=100)


cbsp_cpnfr = tk.Label(text="Coupon frequency",bg="#ffffff", fg="#000000" )
cbsp_cpnfr.config(font="微軟正黑體 15")
cbsp_cpnfr.place(x=900, y=170)

cbsp_cpnfr1 = tk.Label(text="coupons per year(only used for Bond and Csap)",bg="#D6D6EA", fg="#6B6B91" )
cbsp_cpnfr1.config(font="微軟正黑體 10")
cbsp_cpnfr1.place(x=900, y=205)

csUFR_cpnfr = tk.Entry(font="微軟正黑體 15")
csUFR_cpnfr.config(width=5)
csUFR_cpnfr.place(x=1100, y=170)


cbsp_CRA = tk.Label(text="CRA applied \n to input rates",bg="#ffffff", fg="#000000" )
cbsp_CRA.config(font="微軟正黑體 13")
cbsp_CRA.place(x=900, y=240)

cbsp_CRA1 = tk.Label(text="basispoints",bg="#D6D6EA", fg="#6B6B91" )
cbsp_CRA1.config(font="微軟正黑體 8")
cbsp_CRA1.place(x=900, y=290)

csCRA_en = tk.Entry(font="微軟正黑體 15")
csCRA_en.config(width=5)
csCRA_en.place(x=1100, y=240)


cbsp_UFR = tk.Label(text="UFR",bg="#ffffff", fg="#000000" )
cbsp_UFR.config(font="微軟正黑體 15")
cbsp_UFR.place(x=900, y=310)

cbsp_UFR1 = tk.Label(text="Annual compounded rate",bg="#D6D6EA", fg="#6B6B91" )
cbsp_UFR1.config(font="微軟正黑體 10")
cbsp_UFR1.place(x=900, y=345)

csUFR_en = tk.Entry(font="微軟正黑體 15")
csUFR_en.config(width=5)
csUFR_en.place(x=1100, y=310)


cbsp_minal = tk.Label(text="Minimum alpha",bg="#ffffff", fg="#000000" )
cbsp_minal.config(font="微軟正黑體 15")
cbsp_minal.place(x=900, y=380)

csminal_en = tk.Entry(font="微軟正黑體 15")
csminal_en.config(width=5)
csminal_en.place(x=1100, y=380)


cbsp_Bcnv = tk.Label(text="Bandwith\nconvergence UFR",bg="#ffffff", fg="#000000" )
cbsp_Bcnv.config(font="微軟正黑體 13")
cbsp_Bcnv.place(x=900, y=450)

cbsp_Bcnv1 = tk.Label(text="basispoint intensity",bg="#D6D6EA", fg="#6B6B91" )
cbsp_Bcnv1.config(font="微軟正黑體 8")
cbsp_Bcnv1.place(x=900, y=500)

csBcnv_en = tk.Entry(font="微軟正黑體 15")
csBcnv_en.config(width=5)
csBcnv_en.place(x=1100, y=450)


cbsp_convT = tk.Label(text="Convergence at T=",bg="#ffffff", fg="#000000" )
cbsp_convT.config(font="微軟正黑體 15")
cbsp_convT.place(x=900, y=520)

cbsp_convT1 = tk.Label(text="Years",bg="#D6D6EA", fg="#6B6B91" )
cbsp_convT1.config(font="微軟正黑體 10")
cbsp_convT1.place(x=900, y=555)

csconvT_en = tk.Entry(font="微軟正黑體 15")
csconvT_en.config(width=5)
csconvT_en.place(x=1100, y=520)


cbsp_Liq = tk.Label(text="Liquid?",bg="#ffffff", fg="#000000" )
cbsp_Liq.config(font="微軟正黑體 15")
cbsp_Liq.place(x=900, y=590)

cbsp_UFR1 = tk.Label(text="(1=Y/0=N)",bg="#D6D6EA", fg="#6B6B91" )
cbsp_UFR1.config(font="微軟正黑體 10")
cbsp_UFR1.place(x=900, y=625)

csLiq_en = tk.Entry(font="微軟正黑體 15")
csLiq_en.config(width=5)
csLiq_en.place(x=1100, y=590)

csipt = tk.Button()
csipt.config(fg="#000000", bg="#ffffff", text="Input Data", font="微軟正黑體 15")
csipt.place(x=920, y=680)


# 作圖區


smwspic = tk.Label(text="Smith-Wilson",bg="#ffffff", fg="#000AFF")
smwspic.config(font="微軟正黑體 15")
smwspic.place(x=100, y=50)

swopt = tk.Button()
swopt.config(fg="#000000", bg="#ffffff", text="Export Excel", font="微軟正黑體 15")
swopt.place(x=410, y=310)



cbsppic = tk.Label(text="Cubic-Spline",bg="#ffffff", fg="#000AFF")
cbsppic.config(font="微軟正黑體 15")
cbsppic.place(x=100, y=400)

csopt = tk.Button()
csopt.config(fg="#000000", bg="#ffffff", text="Export Excel", font="微軟正黑體 15")
csopt.place(x=410, y=660)


if __name__ == "__main__":
    plt.use("TkAgg") 
    fig = Figure()

    drawPicsw = tk.Canvas(win, bg="#ffffff", height=250, width=300)
    drawPicsw.place(x=100, y=100) 

    # drawPicsw = Figure(figsize=(0.1,0.1), dpi=100) 
    # drawPicsw.canvas = FigureCanvasTkAgg(fig, master=win)
    # drawPicsw.canvas.draw()
    # drawPicsw.canvas.get_tk_widget().place(x=100, y=100) 

    drawPiccs = tk.Canvas(win, bg="#ffffff", height=250, width=300)
    drawPiccs.place(x=100, y=450)
    # drawPiccs = Figure(figsize=(0.5,0.5), dpi=100) 
    # drawPiccs.canvas = FigureCanvasTkAgg(fig, master=win)
    # drawPiccs.canvas.draw()
    # drawPiccs.canvas.get_tk_widget().place(x=100, y=650)    

# grid(row=0, column=0, rowspan=3)


# 資料輸出區









win.mainloop()
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "C:\Users\User\Anaconda3\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\Users\User\Anaconda3\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Users\User\Anaconda3\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "C:\Users\User\Anaconda3\lib\site-packages\ipykernel\kernelapp.py", line 486, in start
#     self.io_loop.start()
# ...

# %%
# Out:
# <tkinter.Entry object .!entry>

# %%
import os

def fun():
    os.system("Smith-Wilson Model.ipynb.ipynb")
fun()

# %%
import SWmodel
# Out:
# 正在運行 日期==1999/3/31
# 正在運行 日期==1999/4/30
# 正在運行 日期==1999/5/31
# 正在運行 日期==1999/6/30
# 正在運行 日期==1999/7/30
# 正在運行 日期==1999/8/31
# 正在運行 日期==1999/9/30
# 正在運行 日期==1999/10/29
# 正在運行 日期==1999/11/30
# 正在運行 日期==1999/12/31
# 正在運行 日期==2000/1/31
# 正在運行 日期==2000/2/29
# 正在運行 日期==2000/3/31
# 正在運行 日期==2000/4/28
# 正在運行 日期==2000/5/31
# 正在運行 日期==2000/6/30
# 正在運行 日期==2000/7/31
# 正在運行 日期==2000/8/31
# 正在運行 日期==2000/9/29
# 正在運行 日期==2000/10/31
# 正在運行 日期==2000/11/30
# 正在運行 日期==2000/12/29
# 正在運行 日期==2001/1/31
# 正在運行 日期==2001/2/28
# 正在運行 日期==2001/3/30
# 正在運行 日期==2001/4/30
# 正在運行 日期==2001/5/31
# 正在運行 日期==2001/6/29
# 正在運行 日期==2001/7/31
# 正在運行 日期==2001/8/31
# 正在運行 日期==2001/9/28
# 正在運行 日期==2001/10/31
# 正在運行 日期==2001/11/30
# 正在運行 日期==2001/12/31
# 正在運行 日期==2002/1/31
# 正在運行 日期==2002/2/28
# 正在運行 日期==2002/3/29
# 正在運行 日期==2002/4/30
# 正在運行 日期==2002/5/31
# 正在運行 日期==2002/6/28
# 正在運行 日期==2002/7/31
# 正在運行 日期==2002/8/30
# 正在運行 日期==2002/9/30
# 正在運行 日期==2002/10/31
# 正在運行 日期==2002/11/29
# 正在運行 日期==2002/12/31
# 正在運行 日期==2003/1/31
# ...
