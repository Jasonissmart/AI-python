# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator         #To increase the number of data
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Activation, Dropout, Flatten, Dense
from tensorflow.keras import backend as K
from tensorflow.keras import optimizers
import json

image_width, image_height = 64, 64
if K.image_data_format() == 'channels_first':
    input_shape = (1, image_width, image_height)
else:
    input_shape = (image_width, image_height, 1)

train_dir = r'C:\Users\User\Desktop\程式\AI-python\naruto-handsigns-predict-dl-master\dataset'                #input-to train
validation_dir = r'C:\Users\User\Desktop\程式\AI-python\naruto-handsigns-predict-dl-master\dataset'            #input-to test
save_dir=r'C:\Users\User\Desktop\程式\AI-python\naruto-handsigns-predict-dl-master\save'      #Data generated by ImageDataGenerator

train_samples = 35                        #input
validation_samples = 35                    #input

batch_size = 16
epochs = 30

#Model Create
model = Sequential()
model.add(Conv2D(64, (3, 3), input_shape=input_shape))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(128))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(8))                             #input
model.add(Activation('softmax'))

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

#Generate Data
#參考資料: https://zhuanlan.zhihu.com/p/30197320
#shear_range:错切变换, zoom_range:让图片在长或宽的方向进行放大, horizontal_flip:随机对图片执行水平翻转操作
train_datagen = ImageDataGenerator(shear_range=0.4, zoom_range=0.0, horizontal_flip=True)
train_generator = train_datagen.flow_from_directory(train_dir, target_size=(image_width, image_height), batch_size=batch_size, 
                                                    color_mode="grayscale", class_mode='categorical',save_to_dir=save_dir)
test_datagen = ImageDataGenerator()
validation_generator = test_datagen.flow_from_directory(validation_dir, target_size=(image_width, image_height), batch_size=batch_size, 
                                                        color_mode="grayscale", class_mode='categorical',save_to_dir=save_dir)

# steps_per_epoch設置說明: https://www.pyimagesearch.com/2018/12/24/how-to-use-keras-fit-and-fit_generator-a-hands-on-tutorial/
model.fit_generator(train_generator, steps_per_epoch= train_samples / batch_size, epochs=epochs, validation_data=validation_generator, 
                    validation_steps= validation_samples / batch_size)


model_json = model.to_json()
with open("model_in_json.json", "w") as json_file:
    json.dump(model_json, json_file)


model.save_weights('model_weights.h5')
# Out:
# Found 35 images belonging to 8 classes.
# Found 35 images belonging to 8 classes.
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 2.1875 steps, validate for 2.1875 steps
# Epoch 1/30
# 3/2 [=========================================] - 1s 335ms/step - loss: 65.1411 - accuracy: 0.1429 - val_loss: 33.4859 - val_accuracy: 0.4857
# Epoch 2/30
# 3/2 [=========================================] - 1s 173ms/step - loss: 19.5704 - accuracy: 0.2571 - val_loss: 4.2769 - val_accuracy: 0.6857
# Epoch 3/30
# 3/2 [=========================================] - 0s 159ms/step - loss: 10.3018 - accuracy: 0.4857 - val_loss: 0.7427 - val_accuracy: 0.8286
# Epoch 4/30
# 3/2 [=========================================] - 1s 173ms/step - loss: 2.5285 - accuracy: 0.5714 - val_loss: 0.3279 - val_accuracy: 0.9429
# Epoch 5/30
# 3/2 [=========================================] - 1s 232ms/step - loss: 1.5690 - accuracy: 0.7714 - val_loss: 0.0689 - val_accuracy: 0.9714
# Epoch 6/30
# 3/2 [=========================================] - 1s 255ms/step - loss: 0.4543 - accuracy: 0.8571 - val_loss: 0.0293 - val_accuracy: 1.0000
# Epoch 7/30
# 3/2 [=========================================] - 1s 174ms/step - loss: 0.3983 - accuracy: 0.8000 - val_loss: 0.0213 - val_accuracy: 1.0000
# Epoch 8/30
# 3/2 [=========================================] - 0s 163ms/step - loss: 0.2404 - accuracy: 0.8571 - val_loss: 0.0099 - val_accuracy: 1.0000
# Epoch 9/30
# 3/2 [=========================================] - 1s 299ms/step - loss: 0.0627 - accuracy: 0.9714 - val_loss: 0.0057 - val_accuracy: 1.0000
# Epoch 10/30
# 3/2 [=========================================] - 1s 371ms/step - loss: 0.0251 - accuracy: 1.0000 - val_loss: 0.0033 - val_accuracy: 1.0000
# Epoch 11/30
# 3/2 [=========================================] - 1s 373ms/step - loss: 0.1297 - accuracy: 0.9429 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 12/30
# 3/2 [=========================================] - 1s 234ms/step - loss: 0.0102 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 13/30
# 3/2 [=========================================] - 1s 250ms/step - loss: 0.1273 - accuracy: 0.9429 - val_loss: 5.4037e-04 - val_accuracy: 1.0000
# Epoch 14/30
# 3/2 [=========================================] - 1s 187ms/step - loss: 0.0616 - accuracy: 0.9714 - val_loss: 3.7578e-04 - val_accuracy: 1.0000
# Epoch 15/30
# 3/2 [=========================================] - 1s 190ms/step - loss: 0.0400 - accuracy: 1.0000 - val_loss: 2.8989e-04 - val_accuracy: 1.0000
# Epoch 16/30
# 3/2 [=========================================] - 1s 210ms/step - loss: 0.0083 - accuracy: 1.0000 - val_loss: 2.2746e-04 - val_accuracy: 1.0000
# Epoch 17/30
# 3/2 [=========================================] - 1s 267ms/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 1.8684e-04 - val_accuracy: 1.0000
# Epoch 18/30
# 3/2 [=========================================] - 1s 208ms/step - loss: 0.0157 - accuracy: 1.0000 - val_loss: 1.4436e-04 - val_accuracy: 1.0000
# Epoch 19/30
# 3/2 [=========================================] - 1s 202ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 1.1421e-04 - val_accuracy: 1.0000
# Epoch 20/30
# 3/2 [=========================================] - 1s 195ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 9.1908e-05 - val_accuracy: 1.0000
# Epoch 21/30
# 3/2 [=========================================] - 1s 183ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 7.2955e-05 - val_accuracy: 1.0000
# Epoch 22/30
# 3/2 [=========================================] - 0s 140ms/step - loss: 0.0191 - accuracy: 1.0000 - val_loss: 5.9328e-05 - val_accuracy: 1.0000
# Epoch 23/30
# 3/2 [=========================================] - 1s 188ms/step - loss: 0.0401 - accuracy: 0.9714 - val_loss: 3.0577e-05 - val_accuracy: 1.0000
# Epoch 24/30
# 3/2 [=========================================] - 1s 211ms/step - loss: 0.0063 - accuracy: 1.0000 - val_loss: 1.9534e-05 - val_accuracy: 1.0000
# Epoch 25/30
# 3/2 [=========================================] - 0s 157ms/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 1.4546e-05 - val_accuracy: 1.0000
# Epoch 26/30
# 3/2 [=========================================] - 0s 161ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 1.1633e-05 - val_accuracy: 1.0000
# Epoch 27/30
# 3/2 [=========================================] - 1s 193ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 9.7168e-06 - val_accuracy: 1.0000
# Epoch 28/30
# 3/2 [=========================================] - 0s 163ms/step - loss: 0.0170 - accuracy: 1.0000 - val_loss: 8.5395e-06 - val_accuracy: 1.0000
# Epoch 29/30
# 3/2 [=========================================] - 1s 189ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 7.8947e-06 - val_accuracy: 1.0000
# Epoch 30/30
# 3/2 [=========================================] - 1s 261ms/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 7.3282e-06 - val_accuracy: 1.0000
