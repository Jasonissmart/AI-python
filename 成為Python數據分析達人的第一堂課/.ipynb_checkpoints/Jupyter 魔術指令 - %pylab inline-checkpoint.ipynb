# %%
# %pylab inline
#inline 代表畫圖直接在瀏覽器顯示
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
pi
# Out:
# 3.141592653589793

# %%
plot([2,10,5,13])

# %%
randn(10)
#從平均值是2標準差是1的亂數中取出
# Out:
# array([ 0.48315398,  0.96470706,  0.01209062, -0.64729864, -1.03634008,
#         0.07833562,  0.46137591,  0.01323333,  0.94569507, -0.70025019])

# %%
plot(randn(100))

# %%
plot([-2,3,7,8],[-5,4,7,8])
#先輸入X座標再輸入Y座標
